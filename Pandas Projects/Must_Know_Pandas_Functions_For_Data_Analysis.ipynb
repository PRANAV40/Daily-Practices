# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {'age':[25,22,19,20,27,21,32,45,23,29],
        'gender':['M','F','F','M','F','M','F','M','M','F'],
        'score':[92,79,93,90,79,88,95,73,84,86]}
df = pd.DataFrame(data)
df
# Out:
#    age gender  score
# 0   25      M     92
# 1   22      F     79
# 2   19      F     93
# 3   20      M     90
# 4   27      F     79
# 5   21      M     88
# 6   32      F     95
# 7   45      M     73
# 8   23      M     84
# 9   29      F     86

# %% [markdown]
# **Value Count**

# %%
df['gender'].value_counts()
# Out:
# gender
# M    5
# F    5
# Name: count, dtype: int64

# %%
df['gender'].value_counts(normalize=True)
# Out:
# gender
# M    0.5
# F    0.5
# Name: proportion, dtype: float64

# %% [markdown]
# **Where**

# %%
df.where(df['age']>25,other=0)
# Out:
#    age gender  score
# 0    0      0      0
# 1    0      0      0
# 2    0      0      0
# 3    0      0      0
# 4   27      F     79
# 5    0      0      0
# 6   32      F     95
# 7   45      M     73
# 8    0      0      0
# 9   29      F     86

# %%
f1 = df['age']>25
f2 = df['gender']=='F'

# %%
df[df.where(f1 & f2,other =0).all(1)]
# Out:
#    age gender  score
# 4   27      F     79
# 6   32      F     95
# 9   29      F     86

# %% [markdown]
# **isin()**

# %%
df[df['age'].isin([20,25])]
# Out:
#    age gender  score
# 0   25      M     92
# 3   20      M     90

# %%
df[df[['age','gender']].isin({'age':[20,25],'génder':['M']})]
# Out:
#     age gender  score
# 0  25.0    NaN    NaN
# 1   NaN    NaN    NaN
# 2   NaN    NaN    NaN
# 3  20.0    NaN    NaN
# 4   NaN    NaN    NaN
# 5   NaN    NaN    NaN
# 6   NaN    NaN    NaN
# 7   NaN    NaN    NaN
# 8   NaN    NaN    NaN
# 9   NaN    NaN    NaN

# %% [markdown]
# # **cut and qcut**

# %%
df
# Out:
#    age gender  score
# 0   25      M     92
# 1   22      F     79
# 2   19      F     93
# 3   20      M     90
# 4   27      F     79
# 5   21      M     88
# 6   32      F     95
# 7   45      M     73
# 8   23      M     84
# 9   29      F     86

# %%
df['score_bins'] = pd.cut(df['score'],bins=[60,70,80,90,100])

# %%
df
# Out:
#    age gender  score score_bins
# 0   25      M     92  (90, 100]
# 1   22      F     79   (70, 80]
# 2   19      F     93  (90, 100]
# 3   20      M     90   (80, 90]
# 4   27      F     79   (70, 80]
# 5   21      M     88   (80, 90]
# 6   32      F     95  (90, 100]
# 7   45      M     73   (70, 80]
# 8   23      M     84   (80, 90]
# 9   29      F     86   (80, 90]

# %%
age_bins = pd.qcut(df['age'],4)

# %%
age_bins
# Out:
# 0       (24.0, 28.5]
# 1      (21.25, 24.0]
# 2    (18.999, 21.25]
# 3    (18.999, 21.25]
# 4       (24.0, 28.5]
# 5    (18.999, 21.25]
# 6       (28.5, 45.0]
# 7       (28.5, 45.0]
# 8      (21.25, 24.0]
# 9       (28.5, 45.0]
# Name: age, dtype: category
# Categories (4, interval[float64, right]): [(18.999, 21.25] < (21.25, 24.0] < (24.0, 28.5] <
#                                            (28.5, 45.0]]

# %% [markdown]
# **Groupby**

# %%
grouped = df.groupby('gender')

# %%
grouped

# %%
grouped['score'].mean()
# Out:
# gender
# F    86.4
# M    85.4
# Name: score, dtype: float64

# %%
grouped['score'].agg(['mean','sum','count'])
# Out:
#         mean  sum  count
# gender
# F       86.4  432      5
# M       85.4  427      5

# %%
df.groupby('gender').agg({'age':'max','score':'mean'})
# Out:
#         age  score
# gender
# F        32   86.4
# M        45   85.4

# %% [markdown]
# # **Pivot_Table**

# %%
df
# Out:
#    age gender  score score_bins
# 0   25      M     92  (90, 100]
# 1   22      F     79   (70, 80]
# 2   19      F     93  (90, 100]
# 3   20      M     90   (80, 90]
# 4   27      F     79   (70, 80]
# 5   21      M     88   (80, 90]
# 6   32      F     95  (90, 100]
# 7   45      M     73   (70, 80]
# 8   23      M     84   (80, 90]
# 9   29      F     86   (80, 90]

# %%
df.pivot_table(index='gender',values='score',aggfunc='mean')
# Out:
#         score
# gender
# F        86.4
# M        85.4

# %%
df.pivot_table(index=['gender','age'],values='score',aggfunc='mean')
# Out:
#             score
# gender age
# F      19    93.0
#        22    79.0
#        27    79.0
#        29    86.0
#        32    95.0
# M      20    90.0
#        21    88.0
#        23    84.0
#        25    92.0
#        45    73.0

# %%
df.pivot_table(index=['gender','age'],values='score',aggfunc=['sum','mean','count'])
# Out:
#              sum  mean count
#            score score score
# gender age
# F      19     93  93.0     1
#        22     79  79.0     1
#        27     79  79.0     1
#        29     86  86.0     1
#        32     95  95.0     1
# M      20     90  90.0     1
#        21     88  88.0     1
#        23     84  84.0     1
#        25     92  92.0     1
#        45     73  73.0     1

# %% [markdown]
# # **nlargest and nsmallest**

# %%
df
# Out:
#    age gender  score score_bins
# 0   25      M     92  (90, 100]
# 1   22      F     79   (70, 80]
# 2   19      F     93  (90, 100]
# 3   20      M     90   (80, 90]
# 4   27      F     79   (70, 80]
# 5   21      M     88   (80, 90]
# 6   32      F     95  (90, 100]
# 7   45      M     73   (70, 80]
# 8   23      M     84   (80, 90]
# 9   29      F     86   (80, 90]

# %%
df['score'].nlargest(3)
# Out:
# 6    95
# 2    93
# 0    92
# Name: score, dtype: int64

# %%
df.nlargest(3,'score')
# Out:
#    age gender  score score_bins
# 6   32      F     95  (90, 100]
# 2   19      F     93  (90, 100]
# 0   25      M     92  (90, 100]

# %%
df['score'].nsmallest(3)
# Out:
# 7    73
# 1    79
# 4    79
# Name: score, dtype: int64

# %%
df.nsmallest(3,'score')
# Out:
#    age gender  score score_bins
# 7   45      M     73   (70, 80]
# 1   22      F     79   (70, 80]
# 4   27      F     79   (70, 80]

# %% [markdown]
# **Query**

# %%
df
# Out:
#    age gender  score score_bins
# 0   25      M     92  (90, 100]
# 1   22      F     79   (70, 80]
# 2   19      F     93  (90, 100]
# 3   20      M     90   (80, 90]
# 4   27      F     79   (70, 80]
# 5   21      M     88   (80, 90]
# 6   32      F     95  (90, 100]
# 7   45      M     73   (70, 80]
# 8   23      M     84   (80, 90]
# 9   29      F     86   (80, 90]

# %%
df.query('age>25')
# Out:
#    age gender  score score_bins
# 4   27      F     79   (70, 80]
# 6   32      F     95  (90, 100]
# 7   45      M     73   (70, 80]
# 9   29      F     86   (80, 90]

# %%
df.query('gender=="F"')
# Out:
#    age gender  score score_bins
# 1   22      F     79   (70, 80]
# 2   19      F     93  (90, 100]
# 4   27      F     79   (70, 80]
# 6   32      F     95  (90, 100]
# 9   29      F     86   (80, 90]

# %%
df.query('age>25 and gender=="F"')
# Out:
#    age gender  score score_bins
# 4   27      F     79   (70, 80]
# 6   32      F     95  (90, 100]
# 9   29      F     86   (80, 90]

# %% [markdown]
# # **sort_values**

# %%
df
# Out:
#    age gender  score score_bins
# 0   25      M     92  (90, 100]
# 1   22      F     79   (70, 80]
# 2   19      F     93  (90, 100]
# 3   20      M     90   (80, 90]
# 4   27      F     79   (70, 80]
# 5   21      M     88   (80, 90]
# 6   32      F     95  (90, 100]
# 7   45      M     73   (70, 80]
# 8   23      M     84   (80, 90]
# 9   29      F     86   (80, 90]

# %%
df.sort_values(by='age',ascending=False)
# Out:
#    age gender  score score_bins
# 7   45      M     73   (70, 80]
# 6   32      F     95  (90, 100]
# 9   29      F     86   (80, 90]
# 4   27      F     79   (70, 80]
# 0   25      M     92  (90, 100]
# 8   23      M     84   (80, 90]
# 1   22      F     79   (70, 80]
# 5   21      M     88   (80, 90]
# 3   20      M     90   (80, 90]
# 2   19      F     93  (90, 100]

# %% [markdown]
# # **Apply**

# %%
df
# Out:
#    age gender  score score_bins
# 0   25      M     92  (90, 100]
# 1   22      F     79   (70, 80]
# 2   19      F     93  (90, 100]
# 3   20      M     90   (80, 90]
# 4   27      F     79   (70, 80]
# 5   21      M     88   (80, 90]
# 6   32      F     95  (90, 100]
# 7   45      M     73   (70, 80]
# 8   23      M     84   (80, 90]
# 9   29      F     86   (80, 90]

# %%
df['gender_lower']=df['gender'].apply(str.lower)

# %%
df
# Out:
#    age gender  score score_bins gender_lower
# 0   25      M     92  (90, 100]            m
# 1   22      F     79   (70, 80]            f
# 2   19      F     93  (90, 100]            f
# 3   20      M     90   (80, 90]            m
# 4   27      F     79   (70, 80]            f
# 5   21      M     88   (80, 90]            m
# 6   32      F     95  (90, 100]            f
# 7   45      M     73   (70, 80]            m
# 8   23      M     84   (80, 90]            m
# 9   29      F     86   (80, 90]            f

# %%
df['age_squared']=df['age'].apply(lambda x : x**2)

# %%
df
# Out:
#    age gender  score score_bins gender_lower  age_squared
# 0   25      M     92  (90, 100]            m          625
# 1   22      F     79   (70, 80]            f          484
# 2   19      F     93  (90, 100]            f          361
# 3   20      M     90   (80, 90]            m          400
# 4   27      F     79   (70, 80]            f          729
# 5   21      M     88   (80, 90]            m          441
# 6   32      F     95  (90, 100]            f         1024
# 7   45      M     73   (70, 80]            m         2025
# 8   23      M     84   (80, 90]            m          529
# 9   29      F     86   (80, 90]            f          841

# %%
def age(x):
    return x**2

# %%
df['age_squared_uf']=df['age'].apply(age)

# %%
df
# Out:
#    age gender  score score_bins gender_lower  age_squared  age_squared_uf
# 0   25      M     92  (90, 100]            m          625             625
# 1   22      F     79   (70, 80]            f          484             484
# 2   19      F     93  (90, 100]            f          361             361
# 3   20      M     90   (80, 90]            m          400             400
# 4   27      F     79   (70, 80]            f          729             729
# 5   21      M     88   (80, 90]            m          441             441
# 6   32      F     95  (90, 100]            f         1024            1024
# 7   45      M     73   (70, 80]            m         2025            2025
# 8   23      M     84   (80, 90]            m          529             529
# 9   29      F     86   (80, 90]            f          841             841
